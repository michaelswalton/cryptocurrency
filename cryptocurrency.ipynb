# %% [markdown]
# # CryptoCurrency Notebook

# %% [markdown]
# ### Install coinmarketcap
# This is a python wrapper to the cryptocurrency API.  More often than not, I try to leverage python wrappers over direct API calls, because many of them have already worked out the kinks, added error handling, etc.

# %%
# !pip install coinmarketcap
# Out:
# Collecting coinmarketcap
#   Downloading https://files.pythonhosted.org/packages/a8/da/c64662a91905017f237f5ff2778b68638946b0d6268513efadd4d1363669/coinmarketcap-5.0.3.tar.gz
# Requirement already satisfied: requests>=2.18.4 in /usr/local/envs/py2env/lib/python2.7/site-packages (from coinmarketcap) (2.18.4)
# Collecting requests_cache>=0.4.13 (from coinmarketcap)
#   Downloading https://files.pythonhosted.org/packages/00/62/9e45a38988cb48c474805a1626439f4d9a486a042bd077af888fa8b17a64/requests_cache-0.4.13-py2.py3-none-any.whl
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests>=2.18.4->coinmarketcap) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests>=2.18.4->coinmarketcap) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests>=2.18.4->coinmarketcap) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests>=2.18.4->coinmarketcap) (2018.8.13)
# Building wheels for collected packages: coinmarketcap
#   Running setup.py bdist_wheel for coinmarketcap ... done
#   Stored in directory: /content/.cache/pip/wheels/5c/73/ec/47f4d3160b8d215cc223937a3886eccfc690cd3dbb5152ab42
# Successfully built coinmarketcap
# Installing collected packages: requests-cache, coinmarketcap
# Successfully installed coinmarketcap-5.0.3 requests-cache-0.4.13

# %% [markdown]
# ### Install pandas
# For small amounts of data, I like to leverage pandas for data manipulation.

# %%
# !pip install pandas
# !pip install google.cloud.bigquery
# Out:
# Requirement already satisfied: pandas in /usr/local/envs/py2env/lib/python2.7/site-packages (0.22.0)
# Requirement already satisfied: python-dateutil in /usr/local/envs/py2env/lib/python2.7/site-packages (from pandas) (2.5.0)
# Requirement already satisfied: pytz>=2011k in /usr/local/envs/py2env/lib/python2.7/site-packages (from pandas) (2016.7)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from pandas) (1.14.0)
# Requirement already satisfied: six>=1.5 in /usr/local/envs/py2env/lib/python2.7/site-packages (from python-dateutil->pandas) (1.10.0)
# Collecting google.cloud.bigquery
#   Downloading https://files.pythonhosted.org/packages/72/e1/1ae3f8024e1d011bc567d54ec81e8c9afd08d107a326bd109e578475415d/google_cloud_bigquery-1.6.0-py2.py3-none-any.whl (83kB)
#     100% |████████████████████████████████| 92kB 2.9MB/s ta 0:00:011
# Requirement already satisfied: google-resumable-media>=0.2.1 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google.cloud.bigquery) (0.3.1)
# Requirement already satisfied: google-cloud-core<0.29dev,>=0.28.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google.cloud.bigquery) (0.28.1)
# Collecting google-api-core<2.0.0dev,>=1.0.0 (from google.cloud.bigquery)
#   Downloading https://files.pythonhosted.org/packages/e4/3a/f9a5746a4d1c03e4ae6d4fdea0b4275cd80320dde7b2a44439cf9e913e33/google_api_core-1.5.0-py2.py3-none-any.whl (62kB)
#     100% |████████████████████████████████| 71kB 5.8MB/s ta 0:00:011
# Requirement already satisfied: six in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-resumable-media>=0.2.1->google.cloud.bigquery) (1.10.0)
# Requirement already satisfied: protobuf>=3.4.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (3.5.2)
# Requirement already satisfied: pytz in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (2016.7)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (2.18.4)
# Requirement already satisfied: google-auth<2.0.0dev,>=0.4.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (1.5.1)
# Requirement already satisfied: futures>=3.2.0; python_version < "3.2" in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (3.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.5.3 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (1.5.3)
# Requirement already satisfied: setuptools>=34.0.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (40.0.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (2018.8.13)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-auth<2.0.0dev,>=0.4.0->google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (0.2.2)
# Requirement already satisfied: cachetools>=2.0.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-auth<2.0.0dev,>=0.4.0->google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (2.1.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-auth<2.0.0dev,>=0.4.0->google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (3.4.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.1 in /usr/local/envs/py2env/lib/python2.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0.0dev,>=0.4.0->google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (0.4.4)
# google-cloud-monitoring 0.28.0 has requirement google-api-core<0.2.0dev,>=0.1.1, but you'll have google-api-core 1.5.0 which is incompatible.
# google-cloud-dataflow 2.0.0 has requirement google-cloud-bigquery<0.24.0,>=0.23.0, but you'll have google-cloud-bigquery 1.6.0 which is incompatible.
# google-cloud-dataflow 2.0.0 has requirement httplib2<0.10,>=0.8, but you'll have httplib2 0.11.3 which is incompatible.
# google-cloud-dataflow 2.0.0 has requirement protobuf==3.2.0, but you'll have protobuf 3.5.2 which is incompatible.
# Installing collected packages: google-api-core, google.cloud.bigquery
#   Found existing installation: google-api-core 0.1.4
#     Uninstalling google-api-core-0.1.4:
#       Successfully uninstalled google-api-core-0.1.4
# Successfully installed google-api-core-1.5.0 google.cloud.bigquery

# %% [markdown]
# ### Import csv, Market, and pandas
# Import the necessary libraries and setup the API connection.

# %%
import csv
from coinmarketcap import Market
import pandas as pd

coinmarketcap = Market()

# %% [markdown]
# ### Max Loops
# By querying the listings, I get a number of records available in the ticker.  By doing this, I'll be able to control my loop later, so I get ticker information in chunks of 100 records (the max for that API).

# %%
listings_return = coinmarketcap.listings()
listings_df = pd.DataFrame.from_dict(listings_return['data'])
max_loop = listings_df['id'].count()
max_loop
# Out:
# 2105

# %% [markdown]
# ### Run the Loop
# Loop through the API to get every record.  This process needs to transpose the data correctly into columns and then append each loop to a persistent "full" dataframe.

# %%
j = 1
while j < max_loop:
    ticker_return = coinmarketcap.ticker(start=j, limit=100)
    ticker_df = pd.DataFrame.from_dict(ticker_return['data'])
    if ticker_df.shape[0] != 0:
        ticker_trans = ticker_df.transpose()
        if j == 1:
            ticker_full = ticker_trans
        else:
            ticker_full = ticker_full.append(ticker_trans)
        j += 100
    
ticker_full
# Out:
#      circulating_supply    id last_updated   max_supply  \
# 1           1.73293e+07     1   1539901527      2.1e+07
# 1027        1.02655e+08  1027   1539901534         None
# 1042         3.7456e+10  1042   1539901524         None
# 109         1.09399e+10   109   1539901507      2.1e+10
# 1104            1.1e+07  1104   1539901524         None
# 1168        8.66399e+06  1168   1539901528      2.1e+07
# 1169        5.67812e+07  1169   1539901530         None
# 118         2.88087e+10   118   1539901511         None
# 1214        1.11302e+08  1214   1539901530         None
# 1229              2e+06  1229   1539901526         None
# 1230        2.80232e+08  1230   1539901527         None
# 1274              1e+08  1274   1539901526         None
# 131         8.38878e+06   131   1539901510     1.89e+07
# 1320        9.98999e+08  1320   1539901527  9.98999e+08
# 1321        1.05375e+08  1321   1539901528         None
# 1343        9.90581e+07  1343   1539901527         None
# 1376            6.5e+07  1376   1539901526        1e+08
# 1437        5.04212e+06  1437   1539901530         None
# 1455        9.59242e+08  1455   1539901528         None
# 1518             728228  1518   1539901528         None
# 1521        1.10185e+08  1521   1539901530         None
# 1567        1.33248e+08  1567   1539901532  1.33248e+08
# 1586        1.05794e+08  1586   1539901532         None
# 1684        8.89711e+07  1684   1539901533         None
# 1697              1e+09  1697   1539901532         None
# 1698        4.96214e+06  1698   1539901554      2.1e+07
# 1700         2.3302e+08  1700   1539901556         None
# 1703         5.2787e+07  1703   1539901532        1e+08
# 1720        2.77953e+09  1720   1539901535  2.77953e+09
# 1727        5.76224e+07  1727   1539901530         None
# ...                 ...   ...          ...          ...
# 317                None   317   1539901573         None
# 3183               None  3183   1539901547         None
# 3190               None  3190   1539901550         None
# 3191               None  3191   1539901551         None
# 3212               None  3212   1539901549         None
# 3226               None  3226   1539901549         None
# 3238               None  3238   1539901550         None
# 3299               None  3299   1539809874         None
# 3300               None  3300   1539901550         None
# 3310               None  3310   1539901552         None
# 3367               None  3367   1539901551         None
# 337                None   337   1539096858         None
# 3406               None  3406   1539901553         None
# 3425               None  3425   1539901552         None
# 3458               None  3458   1539901553         None
# 3461               None  3461   1539901553         None
# 353                None   353   1539864322         None
# 385                None   385   1538903117         None
# 411                None   411   1539865757         None
# 549                None   549   1539901580         None
# 70                 None    70   1539901564         None
# 733                None   733   1539901586         None
# 841                None   841   1539864326         None
# 89                 None    89   1539901565         None
# 918                None   918   1539901589         None
# 1783               None  1783   1539875131         None
# 2114               None  2114   1534576978         None
# 2331               None  2331   1525799359      1.6e+09
# 2409               None  2409   1535117806         None
# 3260               None  3260   1539875696         None
#
#                        name  \
# 1                   Bitcoin
# 1027               Ethereum
# 1042                Siacoin
# 109                DigiByte
# 1104                  Augur
# 1168                 Decred
# 1169                   PIVX
# 118                ReddCoin
# 1214                   Lisk
# 1229               DigixDAO
# 1230                  Steem
# 1274                  Waves
# 131                    Dash
# 1320                  Ardor
# 1321       Ethereum Classic
# 1343                Stratis
# 1376                    NEO
# 1437                  Zcash
# 1455                  Golem
# 1518                  Maker
# 1521                 Komodo
# 1567                   Nano
# 1586                    Ark
# 1684                   Qtum
# 1697  Basic Attention Token
# 1698                Horizen
# 1700              Aeternity
# 1703          Metaverse ETP
# 1720                   IOTA
# 1727                 Bancor
# ...                     ...
# 317              CoffeeCoin
# 3183        SecureCloudCoin
# 3190                Defense
# 3191             Rentledger
# 3212             CottonCoin
# 3226                  Adenz
# 3238             ABCC Token
# 3299              XRT Token
# 3300                BFFDoom
# 3310                ALLCOIN
# 3367            CryptalDash
# 337               CryptCoin
# 3406        Block-Chain.com
# 3425             EmaratCoin
# 3458                 ZTCoin
# 3461       PlayCoin [ERC20]
# 353                   Hyper
# 385            Donationcoin
# 411                 SHACoin
# 549             Storjcoin X
# 70                 BetaCoin
# 733                Quotient
# 841               Sharkcoin
# 89                 Mooncoin
# 918                  Bubble
# 1783     UniversalRoyalCoin
# 2114              BT2 [CST]
# 2331                ENTCash
# 2409       EtherDelta Token
# 3260               AMO Coin
#
#                                                  quotes  rank symbol  \
# 1     {u'USD': {u'market_cap': 1.11815360902e+11, u'...     1    BTC
# 1027  {u'USD': {u'market_cap': 20733275066.0, u'perc...     2    ETH
# 1042  {u'USD': {u'market_cap': 239015794.0, u'percen...    38     SC
# 109   {u'USD': {u'market_cap': 255141522.0, u'percen...    36    DGB
# 1104  {u'USD': {u'market_cap': 136715603.0, u'percen...    51    REP
# 1168  {u'USD': {u'market_cap': 337673440.0, u'percen...    27    DCR
# 1169  {u'USD': {u'market_cap': 77579718.0, u'percent...    77   PIVX
# 118   {u'USD': {u'market_cap': 89289109.0, u'percent...    67    RDD
# 1214  {u'USD': {u'market_cap': 318287320.0, u'percen...    29    LSK
# 1229  {u'USD': {u'market_cap': 84541866.0, u'percent...    70    DGD
# 1230  {u'USD': {u'market_cap': 225422632.0, u'percen...    39  STEEM
# 1274  {u'USD': {u'market_cap': 197258231.0, u'percen...    42  WAVES
# 131   {u'USD': {u'market_cap': 1290520302.0, u'perce...    13   DASH
# 1320  {u'USD': {u'market_cap': 112897079.0, u'percen...    58   ARDR
# 1321  {u'USD': {u'market_cap': 1007712704.0, u'perce...    16    ETC
# 1343  {u'USD': {u'market_cap': 134345306.0, u'percen...    52  STRAT
# 1376  {u'USD': {u'market_cap': 1068379743.0, u'perce...    15    NEO
# 1437  {u'USD': {u'market_cap': 595851651.0, u'percen...    20    ZEC
# 1455  {u'USD': {u'market_cap': 147935620.0, u'percen...    48    GNT
# 1518  {u'USD': {u'market_cap': 479211468.0, u'percen...    22    MKR
# 1521  {u'USD': {u'market_cap': 144444487.0, u'percen...    50    KMD
# 1567  {u'USD': {u'market_cap': 259464894.0, u'percen...    33   NANO
# 1586  {u'USD': {u'market_cap': 78191035.0, u'percent...    76    ARK
# 1684  {u'USD': {u'market_cap': 336164044.0, u'percen...    28   QTUM
# 1697  {u'USD': {u'market_cap': 205628170.0, u'percen...    41    BAT
# 1698  {u'USD': {u'market_cap': 65027353.0, u'percent...    92    ZEN
# 1700  {u'USD': {u'market_cap': 287005140.0, u'percen...    30     AE
# 1703  {u'USD': {u'market_cap': 160611670.0, u'percen...    46    ETP
# 1720  {u'USD': {u'market_cap': 1364752503.0, u'perce...    12  MIOTA
# 1727  {u'USD': {u'market_cap': 72968439.0, u'percent...    84    BNT
# ...                                                 ...   ...    ...
# 317   {u'USD': {u'market_cap': None, u'percent_chang...  2022    CFC
# 3183  {u'USD': {u'market_cap': None, u'percent_chang...  2016    SC2
# 3190  {u'USD': {u'market_cap': None, u'percent_chang...  2014    DFS
# 3191  {u'USD': {u'market_cap': None, u'percent_chang...  2026    RTL
# 3212  {u'USD': {u'market_cap': None, u'percent_chang...  2013   COTN
# 3226  {u'USD': {u'market_cap': None, u'percent_chang...  2021    DNZ
# 3238  {u'USD': {u'market_cap': None, u'percent_chang...  2058     AT
# 3299  {u'USD': {u'market_cap': None, u'percent_chang...  2059    XRT
# 3300  {u'USD': {u'market_cap': None, u'percent_chang...  2047    BFF
# 3310  {u'USD': {u'market_cap': None, u'percent_chang...  2060    ALC
# 3367  {u'USD': {u'market_cap': None, u'percent_chang...  2057    CRD
# 337   {u'USD': {u'market_cap': None, u'percent_chang...  2064  CRYPT
# 3406  {u'USD': {u'market_cap': None, u'percent_chang...  2006     BC
# 3425  {u'USD': {u'market_cap': None, u'percent_chang...  2007    AEC
# 3458  {u'USD': {u'market_cap': None, u'percent_chang...  2061     ZT
# 3461  {u'USD': {u'market_cap': None, u'percent_chang...  2062    PLY
# 353   {u'USD': {u'market_cap': None, u'percent_chang...  2065  HYPER
# 385   {u'USD': {u'market_cap': None, u'percent_chang...  2066    DON
# 411   {u'USD': {u'market_cap': None, u'percent_chang...  2067    SHA
# 549   {u'USD': {u'market_cap': None, u'percent_chang...  2043   SJCX
# 70    {u'USD': {u'market_cap': None, u'percent_chang...  2039    BET
# 733   {u'USD': {u'market_cap': None, u'percent_chang...  2028    XQN
# 841   {u'USD': {u'market_cap': None, u'percent_chang...  2068    SAK
# 89    {u'USD': {u'market_cap': None, u'percent_chang...  2003   MOON
# 918   {u'USD': {u'market_cap': None, u'percent_chang...  2049    BUB
# 1783  {u'USD': {u'market_cap': None, u'percent_chang...  2101   UNRC
# 2114  {u'USD': {u'market_cap': None, u'percent_chang...  2102    BT2
# 2331  {u'USD': {u'market_cap': None, u'percent_chang...  2103    ENT
# 2409  {u'USD': {u'market_cap': None, u'percent_chang...  2104    EDT
# 3260  {u'USD': {u'market_cap': None, u'percent_chang...  2105    AMO
#
#      total_supply           website_slug
# 1     1.73293e+07                bitcoin
# 1027  1.02655e+08               ethereum
# 1042   3.7456e+10                siacoin
# 109   1.09399e+10               digibyte
# 1104      1.1e+07                  augur
# 1168  8.66399e+06                 decred
# 1169  5.67812e+07                   pivx
# 118   2.88087e+10               reddcoin
# 1214   1.2654e+08                   lisk
# 1229        2e+06               digixdao
# 1230  2.97206e+08                  steem
# 1274        1e+08                  waves
# 131   8.38878e+06                   dash
# 1320  9.98999e+08                  ardor
# 1321  1.05375e+08       ethereum-classic
# 1343  9.90581e+07                stratis
# 1376        1e+08                    neo
# 1437  5.04212e+06                  zcash
# 1455        1e+09   golem-network-tokens
# 1518        1e+06                  maker
# 1521  1.10185e+08                 komodo
# 1567  1.33248e+08                   nano
# 1586  1.37044e+08                    ark
# 1684  1.00971e+08                   qtum
# 1697      1.5e+09  basic-attention-token
# 1698  4.96214e+06                zencash
# 1700  2.73686e+08              aeternity
# 1703  5.66211e+07              metaverse
# 1720  2.77953e+09                   iota
# 1727  7.80916e+07                 bancor
# ...           ...                    ...
# 317          None             coffeecoin
# 3183  1.54196e+07        securecloudcoin
# 3190       839896                defense
# 3191        1e+10             rentledger
# 3212  5.47562e+06             cottoncoin
# 3226  3.99024e+06                  adenz
# 3238  6.15562e+07             abcc-token
# 3299        5e+08              xrt-token
# 3300      1.6e+10                bffdoom
# 3310        1e+09                allcoin
# 3367        1e+09            cryptaldash
# 337   6.07041e+06              cryptcoin
# 3406     2.47e+08        block-chain-com
# 3425  2.15213e+07             emaratcoin
# 3458        5e+08                 ztcoin
# 3461        1e+09         playcoin-erc20
# 353          None                  hyper
# 385          None           donationcoin
# 411          None                shacoin
# 549         5e+08            storjcoin-x
# 70           None               betacoin
# 733          None               quotient
# 841          None              sharkcoin
# 89    2.24851e+11               mooncoin
# 918        768753                 bubble
# 1783         None     universalroyalcoin
# 2114         None                bt2-cst
# 2331        6e+08                entcash
# 2409      1.5e+09       etherdelta-token
# 3260   1.9679e+10               amo-coin
#
# [2105 rows x 10 columns]

# %% [markdown]
# ### Parse Nested Data
# Within the resulting dataframe is another nested dictionary of data "quotes".  This step parses that data would and creates a new column for each value that I want to store.

# %%
ticker_full['market_cap'] = ticker_full.apply(lambda row: row.quotes['USD'][u'market_cap'], axis=1)
ticker_full['percent_change_7d'] = ticker_full.apply(lambda row: row.quotes['USD'][u'percent_change_7d'], axis=1)
ticker_full['price'] = ticker_full.apply(lambda row: row.quotes['USD'][u'price'], axis=1)
ticker_full['percent_change_1h'] = ticker_full.apply(lambda row: row.quotes['USD'][u'percent_change_1h'], axis=1)
ticker_full['volume_24h'] = ticker_full.apply(lambda row: row.quotes['USD'][u'volume_24h'], axis=1)
ticker_full['percent_change_24h'] = ticker_full.apply(lambda row: row.quotes['USD'][u'percent_change_24h'], axis=1)

ticker_full
# Out:
#      circulating_supply    id last_updated   max_supply  \
# 1           1.73293e+07     1   1539901527      2.1e+07
# 1027        1.02655e+08  1027   1539901534         None
# 1042         3.7456e+10  1042   1539901524         None
# 109         1.09399e+10   109   1539901507      2.1e+10
# 1104            1.1e+07  1104   1539901524         None
# 1168        8.66399e+06  1168   1539901528      2.1e+07
# 1169        5.67812e+07  1169   1539901530         None
# 118         2.88087e+10   118   1539901511         None
# 1214        1.11302e+08  1214   1539901530         None
# 1229              2e+06  1229   1539901526         None
# 1230        2.80232e+08  1230   1539901527         None
# 1274              1e+08  1274   1539901526         None
# 131         8.38878e+06   131   1539901510     1.89e+07
# 1320        9.98999e+08  1320   1539901527  9.98999e+08
# 1321        1.05375e+08  1321   1539901528         None
# 1343        9.90581e+07  1343   1539901527         None
# 1376            6.5e+07  1376   1539901526        1e+08
# 1437        5.04212e+06  1437   1539901530         None
# 1455        9.59242e+08  1455   1539901528         None
# 1518             728228  1518   1539901528         None
# 1521        1.10185e+08  1521   1539901530         None
# 1567        1.33248e+08  1567   1539901532  1.33248e+08
# 1586        1.05794e+08  1586   1539901532         None
# 1684        8.89711e+07  1684   1539901533         None
# 1697              1e+09  1697   1539901532         None
# 1698        4.96214e+06  1698   1539901554      2.1e+07
# 1700         2.3302e+08  1700   1539901556         None
# 1703         5.2787e+07  1703   1539901532        1e+08
# 1720        2.77953e+09  1720   1539901535  2.77953e+09
# 1727        5.76224e+07  1727   1539901530         None
# ...                 ...   ...          ...          ...
# 317                None   317   1539901573         None
# 3183               None  3183   1539901547         None
# 3190               None  3190   1539901550         None
# 3191               None  3191   1539901551         None
# 3212               None  3212   1539901549         None
# 3226               None  3226   1539901549         None
# 3238               None  3238   1539901550         None
# 3299               None  3299   1539809874         None
# 3300               None  3300   1539901550         None
# 3310               None  3310   1539901552         None
# 3367               None  3367   1539901551         None
# 337                None   337   1539096858         None
# 3406               None  3406   1539901553         None
# 3425               None  3425   1539901552         None
# 3458               None  3458   1539901553         None
# 3461               None  3461   1539901553         None
# 353                None   353   1539864322         None
# 385                None   385   1538903117         None
# 411                None   411   1539865757         None
# 549                None   549   1539901580         None
# 70                 None    70   1539901564         None
# 733                None   733   1539901586         None
# 841                None   841   1539864326         None
# 89                 None    89   1539901565         None
# 918                None   918   1539901589         None
# 1783               None  1783   1539875131         None
# 2114               None  2114   1534576978         None
# 2331               None  2331   1525799359      1.6e+09
# 2409               None  2409   1535117806         None
# 3260               None  3260   1539875696         None
#
#                        name  \
# 1                   Bitcoin
# 1027               Ethereum
# 1042                Siacoin
# 109                DigiByte
# 1104                  Augur
# 1168                 Decred
# 1169                   PIVX
# 118                ReddCoin
# 1214                   Lisk
# 1229               DigixDAO
# 1230                  Steem
# 1274                  Waves
# 131                    Dash
# 1320                  Ardor
# 1321       Ethereum Classic
# 1343                Stratis
# 1376                    NEO
# 1437                  Zcash
# 1455                  Golem
# 1518                  Maker
# 1521                 Komodo
# 1567                   Nano
# 1586                    Ark
# 1684                   Qtum
# 1697  Basic Attention Token
# 1698                Horizen
# 1700              Aeternity
# 1703          Metaverse ETP
# 1720                   IOTA
# 1727                 Bancor
# ...                     ...
# 317              CoffeeCoin
# 3183        SecureCloudCoin
# 3190                Defense
# 3191             Rentledger
# 3212             CottonCoin
# 3226                  Adenz
# 3238             ABCC Token
# 3299              XRT Token
# 3300                BFFDoom
# 3310                ALLCOIN
# 3367            CryptalDash
# 337               CryptCoin
# 3406        Block-Chain.com
# 3425             EmaratCoin
# 3458                 ZTCoin
# 3461       PlayCoin [ERC20]
# 353                   Hyper
# 385            Donationcoin
# 411                 SHACoin
# 549             Storjcoin X
# 70                 BetaCoin
# 733                Quotient
# 841               Sharkcoin
# 89                 Mooncoin
# 918                  Bubble
# 1783     UniversalRoyalCoin
# 2114              BT2 [CST]
# 2331                ENTCash
# 2409       EtherDelta Token
# 3260               AMO Coin
#
#                                                  quotes  rank symbol  \
# 1     {u'USD': {u'market_cap': 1.11815360902e+11, u'...     1    BTC
# 1027  {u'USD': {u'market_cap': 20733275066.0, u'perc...     2    ETH
# 1042  {u'USD': {u'market_cap': 239015794.0, u'percen...    38     SC
# 109   {u'USD': {u'market_cap': 255141522.0, u'percen...    36    DGB
# 1104  {u'USD': {u'market_cap': 136715603.0, u'percen...    51    REP
# 1168  {u'USD': {u'market_cap': 337673440.0, u'percen...    27    DCR
# 1169  {u'USD': {u'market_cap': 77579718.0, u'percent...    77   PIVX
# 118   {u'USD': {u'market_cap': 89289109.0, u'percent...    67    RDD
# 1214  {u'USD': {u'market_cap': 318287320.0, u'percen...    29    LSK
# 1229  {u'USD': {u'market_cap': 84541866.0, u'percent...    70    DGD
# 1230  {u'USD': {u'market_cap': 225422632.0, u'percen...    39  STEEM
# 1274  {u'USD': {u'market_cap': 197258231.0, u'percen...    42  WAVES
# 131   {u'USD': {u'market_cap': 1290520302.0, u'perce...    13   DASH
# 1320  {u'USD': {u'market_cap': 112897079.0, u'percen...    58   ARDR
# 1321  {u'USD': {u'market_cap': 1007712704.0, u'perce...    16    ETC
# 1343  {u'USD': {u'market_cap': 134345306.0, u'percen...    52  STRAT
# 1376  {u'USD': {u'market_cap': 1068379743.0, u'perce...    15    NEO
# 1437  {u'USD': {u'market_cap': 595851651.0, u'percen...    20    ZEC
# 1455  {u'USD': {u'market_cap': 147935620.0, u'percen...    48    GNT
# 1518  {u'USD': {u'market_cap': 479211468.0, u'percen...    22    MKR
# 1521  {u'USD': {u'market_cap': 144444487.0, u'percen...    50    KMD
# 1567  {u'USD': {u'market_cap': 259464894.0, u'percen...    33   NANO
# 1586  {u'USD': {u'market_cap': 78191035.0, u'percent...    76    ARK
# 1684  {u'USD': {u'market_cap': 336164044.0, u'percen...    28   QTUM
# 1697  {u'USD': {u'market_cap': 205628170.0, u'percen...    41    BAT
# 1698  {u'USD': {u'market_cap': 65027353.0, u'percent...    92    ZEN
# 1700  {u'USD': {u'market_cap': 287005140.0, u'percen...    30     AE
# 1703  {u'USD': {u'market_cap': 160611670.0, u'percen...    46    ETP
# 1720  {u'USD': {u'market_cap': 1364752503.0, u'perce...    12  MIOTA
# 1727  {u'USD': {u'market_cap': 72968439.0, u'percent...    84    BNT
# ...                                                 ...   ...    ...
# 317   {u'USD': {u'market_cap': None, u'percent_chang...  2022    CFC
# 3183  {u'USD': {u'market_cap': None, u'percent_chang...  2016    SC2
# 3190  {u'USD': {u'market_cap': None, u'percent_chang...  2014    DFS
# 3191  {u'USD': {u'market_cap': None, u'percent_chang...  2026    RTL
# 3212  {u'USD': {u'market_cap': None, u'percent_chang...  2013   COTN
# 3226  {u'USD': {u'market_cap': None, u'percent_chang...  2021    DNZ
# 3238  {u'USD': {u'market_cap': None, u'percent_chang...  2058     AT
# 3299  {u'USD': {u'market_cap': None, u'percent_chang...  2059    XRT
# 3300  {u'USD': {u'market_cap': None, u'percent_chang...  2047    BFF
# 3310  {u'USD': {u'market_cap': None, u'percent_chang...  2060    ALC
# 3367  {u'USD': {u'market_cap': None, u'percent_chang...  2057    CRD
# 337   {u'USD': {u'market_cap': None, u'percent_chang...  2064  CRYPT
# 3406  {u'USD': {u'market_cap': None, u'percent_chang...  2006     BC
# 3425  {u'USD': {u'market_cap': None, u'percent_chang...  2007    AEC
# 3458  {u'USD': {u'market_cap': None, u'percent_chang...  2061     ZT
# 3461  {u'USD': {u'market_cap': None, u'percent_chang...  2062    PLY
# 353   {u'USD': {u'market_cap': None, u'percent_chang...  2065  HYPER
# 385   {u'USD': {u'market_cap': None, u'percent_chang...  2066    DON
# 411   {u'USD': {u'market_cap': None, u'percent_chang...  2067    SHA
# 549   {u'USD': {u'market_cap': None, u'percent_chang...  2043   SJCX
# 70    {u'USD': {u'market_cap': None, u'percent_chang...  2039    BET
# 733   {u'USD': {u'market_cap': None, u'percent_chang...  2028    XQN
# 841   {u'USD': {u'market_cap': None, u'percent_chang...  2068    SAK
# 89    {u'USD': {u'market_cap': None, u'percent_chang...  2003   MOON
# 918   {u'USD': {u'market_cap': None, u'percent_chang...  2049    BUB
# 1783  {u'USD': {u'market_cap': None, u'percent_chang...  2101   UNRC
# 2114  {u'USD': {u'market_cap': None, u'percent_chang...  2102    BT2
# 2331  {u'USD': {u'market_cap': None, u'percent_chang...  2103    ENT
# 2409  {u'USD': {u'market_cap': None, u'percent_chang...  2104    EDT
# 3260  {u'USD': {u'market_cap': None, u'percent_chang...  2105    AMO
#
#      total_supply           website_slug    market_cap  percent_change_7d  \
# 1     1.73293e+07                bitcoin  1.118154e+11               2.73
# 1027  1.02655e+08               ethereum  2.073328e+10               3.29
# 1042   3.7456e+10                siacoin  2.390158e+08               3.81
# 109   1.09399e+10               digibyte  2.551415e+08               0.61
# 1104      1.1e+07                  augur  1.367156e+08               6.53
# 1168  8.66399e+06                 decred  3.376734e+08               4.85
# 1169  5.67812e+07                   pivx  7.757972e+07              17.78
# 118   2.88087e+10               reddcoin  8.928911e+07              -0.75
# 1214   1.2654e+08                   lisk  3.182873e+08              -6.76
# 1229        2e+06               digixdao  8.454187e+07              18.91
# 1230  2.97206e+08                  steem  2.254226e+08               1.49
# 1274        1e+08                  waves  1.972582e+08               4.72
# 131   8.38878e+06                   dash  1.290520e+09              -2.94
# 1320  9.98999e+08                  ardor  1.128971e+08              -2.00
# 1321  1.05375e+08       ethereum-classic  1.007713e+09               0.07
# 1343  9.90581e+07                stratis  1.343453e+08               2.07
# 1376        1e+08                    neo  1.068380e+09               4.26
# 1437  5.04212e+06                  zcash  5.958517e+08               5.78
# 1455        1e+09   golem-network-tokens  1.479356e+08               0.71
# 1518        1e+06                  maker  4.792115e+08               2.58
# 1521  1.10185e+08                 komodo  1.444445e+08              27.78
# 1567  1.33248e+08                   nano  2.594649e+08               5.58
# 1586  1.37044e+08                    ark  7.819104e+07              10.02
# 1684  1.00971e+08                   qtum  3.361640e+08               7.86
# 1697      1.5e+09  basic-attention-token  2.056282e+08              23.36
# 1698  4.96214e+06                zencash  6.502735e+07              -5.40
# 1700  2.73686e+08              aeternity  2.870051e+08              10.60
# 1703  5.66211e+07              metaverse  1.606117e+08              -3.16
# 1720  2.77953e+09                   iota  1.364753e+09              -1.74
# 1727  7.80916e+07                 bancor  7.296844e+07              -2.62
# ...           ...                    ...           ...                ...
# 317          None             coffeecoin           NaN              37.40
# 3183  1.54196e+07        securecloudcoin           NaN             -11.44
# 3190       839896                defense           NaN              40.93
# 3191        1e+10             rentledger           NaN               3.36
# 3212  5.47562e+06             cottoncoin           NaN             -38.69
# 3226  3.99024e+06                  adenz           NaN              55.88
# 3238  6.15562e+07             abcc-token           NaN                NaN
# 3299        5e+08              xrt-token           NaN             -23.74
# 3300      1.6e+10                bffdoom           NaN             -44.43
# 3310        1e+09                allcoin           NaN                NaN
# 3367        1e+09            cryptaldash           NaN              10.56
# 337   6.07041e+06              cryptcoin           NaN                NaN
# 3406     2.47e+08        block-chain-com           NaN              72.69
# 3425  2.15213e+07             emaratcoin           NaN              36.06
# 3458        5e+08                 ztcoin           NaN                NaN
# 3461        1e+09         playcoin-erc20           NaN                NaN
# 353          None                  hyper           NaN               5.11
# 385          None           donationcoin           NaN                NaN
# 411          None                shacoin           NaN             -21.48
# 549         5e+08            storjcoin-x           NaN             -11.71
# 70           None               betacoin           NaN                NaN
# 733          None               quotient           NaN              15.94
# 841          None              sharkcoin           NaN                NaN
# 89    2.24851e+11               mooncoin           NaN                NaN
# 918        768753                 bubble           NaN                NaN
# 1783         None     universalroyalcoin           NaN               4.67
# 2114         None                bt2-cst           NaN                NaN
# 2331        6e+08                entcash           NaN                NaN
# 2409      1.5e+09       etherdelta-token           NaN                NaN
# 3260   1.9679e+10               amo-coin           NaN              19.97
#
#             price  percent_change_1h    volume_24h  percent_change_24h
# 1     6452.392467              -0.44  3.892669e+09               -1.36
# 1027   201.970844              -0.38  1.334204e+09               -2.46
# 1042     0.006381              -0.37  2.318148e+06               -2.47
# 109      0.023322              -0.22  1.985434e+06               -1.34
# 1104    12.428691              -0.13  1.882160e+06               -1.02
# 1168    38.974367              -0.56  6.981695e+05               -1.91
# 1169     1.366293               1.15  1.609862e+07                8.51
# 118      0.003099              -1.06  7.334190e+05               -3.82
# 1214     2.859664              -0.48  6.593141e+06               -4.36
# 1229    42.270933              -0.27  6.892346e+05               -2.76
# 1230     0.804413               0.16  8.589488e+05               -3.93
# 1274     1.972582              -0.20  6.488374e+06               -2.90
# 131    153.838805              -0.56  1.655908e+08               -3.67
# 1320     0.113010              -0.17  8.618693e+05               -3.03
# 1321     9.563125              -0.31  1.336012e+08               -2.54
# 1343     1.356227              -1.81  7.852782e+05               -6.19
# 1376    16.436611              -0.12  3.251764e+08               -1.21
# 1437   118.174855              -0.51  7.061971e+07                0.32
# 1455     0.154221              -0.41  2.471140e+06                0.46
# 1518   658.051626              -0.11  6.517940e+05                1.67
# 1521     1.310925               0.34  1.824727e+06                1.93
# 1567     1.947229               1.11  8.379121e+06               -6.76
# 1586     0.739091              -1.00  6.730106e+05               -6.54
# 1684     3.778352              -0.95  9.532991e+07               -4.74
# 1697     0.205628              -1.76  8.917191e+06               -3.05
# 1698    13.104706              -0.20  5.834690e+05               -5.99
# 1700     1.231673              -0.52  9.276534e+06               -3.24
# 1703     3.042638               0.78  6.548944e+06               -3.92
# 1720     0.491001              -0.34  2.265097e+07               -3.96
# 1727     1.266321              -0.33  4.188644e+06               -2.29
# ...           ...                ...           ...                 ...
# 317      0.000514              -0.39  1.689834e+01                5.36
# 3183     0.001096              -0.09  2.285808e+01               -4.11
# 3190     0.003804              -0.09  3.086302e+01               -4.53
# 3191     0.000387              -0.09  1.299938e+01               -1.29
# 3212     0.011542              -2.90  3.380697e+01               -6.26
# 3226     0.003869              -0.09  1.918756e+01               -1.29
# 3238     0.229161                NaN           NaN                 NaN
# 3299     0.000192                NaN           NaN                 NaN
# 3300     0.000002              -0.39  1.283574e+00               -2.43
# 3310     0.015772                NaN           NaN                 NaN
# 3367     0.012509              -0.09  1.000000e-10               -3.04
# 337      0.050202                NaN           NaN                 NaN
# 3406     0.151519              -0.39  4.545558e+01               -1.02
# 3425     0.113565              -0.09  4.545425e+01               -3.29
# 3458     0.130486                NaN           NaN                 NaN
# 3461     0.142314                NaN           NaN                 NaN
# 353      0.008388                NaN           NaN               -0.46
# 385      0.000262                NaN           NaN                 NaN
# 411      0.000196                NaN           NaN               -0.01
# 549      0.196072               4.26  1.764651e+00                9.35
# 70       0.001221              -0.39  3.700209e+00               -1.59
# 733      0.001957              -0.39  1.046168e+01              -32.92
# 841      0.002666                NaN           NaN               -0.46
# 89       0.000024              -0.19  5.205365e+01                 NaN
# 918      0.006750              -0.39  6.810523e-01              -22.89
# 1783     0.000261                NaN           NaN               -1.00
# 2114     5.323106                NaN           NaN                 NaN
# 2331     0.024932                NaN           NaN                 NaN
# 2409     0.001109                NaN           NaN                 NaN
# 3260     0.001950                NaN           NaN                7.02
#
# [2105 rows x 16 columns]

# %% [markdown]
# ### Drop to CSV
# Using the pandas function to create a CSV from the dataframe, I create a file from the df without the nested quotes column, which has now been split into their own columns.

# %%
ticker_full.drop(columns=['quotes']).to_csv('cryptocurrency_details.csv',index=False, quoting=csv.QUOTE_NONNUMERIC)

# %% [markdown]
# ### gsutil - Copy File to GCS
# __Note:__ The bucket was created manually within the GUI when I created the project.  This could have been done through the command line, as well, but was easier in the interface since I was already there.

# %%
# !gsutil cp cryptocurrency_details.csv gs://hokie-crazy-public/cryptocurrency/cryptocurrent_details.csv
# Out:
# Updates are available for some Cloud SDK components.  To install them,
# please run:
#   $ gcloud components update
#
# Copying file://cryptocurrency_details.csv [Content-Type=text/csv]...
# / [1 files][267.2 KiB/267.2 KiB]
# Operation completed over 1 objects/267.2 KiB.

# %% [markdown]
# ### gsutil - Make the bucket public
# __Note:__ This command adds all users as a read-only user to the bucket where the file above is located.

# %%
# !gsutil iam ch allUsers:objectViewer gs://hokie-crazy-public

# %% [markdown]
# ### Load the BigQuery Library
# __Note:__ This command allows me to use %%bigquery magics to execute queries.  Might not be necessary to load this in DataLab, but to be safe...

# %%
# %load_ext google.cloud.bigquery

# %% [markdown]
# ### How many coins have a USD price greater than $8,000?

# %%
# %%bigquery
# SELECT COUNT(id)
# FROM `hokie-crazy.cryptocurrency.ticker`
# WHERE price > 8000
#
# #3
# Out:
#    f0_
# 0    3

# %% [markdown]
# ### What is the total market cap of the top 100 cryptocurrencies (in USD)?

# %%
# %%bigquery
# SELECT SUM(market_cap)
# FROM (SELECT market_cap, ROW_NUMBER() OVER (ORDER BY market_cap DESC) as row_num FROM `hokie-crazy.cryptocurrency.ticker`) a
# WHERE a.row_num <= 100
#
# #2.027954e+11
# Out:
#             f0_
# 0  2.027954e+11

# %% [markdown]
# ### Which coins have an available supply less than $5M?

# %%
# %%bigquery
# SELECT name
# FROM `hokie-crazy.cryptocurrency.ticker`
# WHERE circulating_supply * price < 5000000
# Out:
#                        name
# 0              CryptoCarbon
# 1                MarteXcoin
# 2                  Bitcloud
# 3      Ultimate Secure Cash
# 4                  BriaCoin
# 5                  Golfcoin
# 6                   Granite
# 7      Gold Pressed Latinum
# 8               HoboNickels
# 9                 CacheCoin
# 10              StarCredits
# 11               Artex Coin
# 12                 ChanCoin
# 13             Coimatic 3.0
# 14                     Ergo
# 15                 Fastcoin
# 16                GrandCoin
# 17                 Megacoin
# 18                 Nyancoin
# 19               EuropeCoin
# 20                  Polcoin
# 21    Uniform Fiscal Object
# 22            Litecoin Plus
# 23                Quebecoin
# 24                  PLNcoin
# 25                Virtacoin
# 26                  Neutron
# 27             MonetaryUnit
# 28                     Bata
# 29              Bolivarcoin
# ...                     ...
# 1161            Tidex Token
# 1162                  Bodhi
# 1163                    AC3
# 1164                  Semux
# 1165                Xchange
# 1166                 Dinero
# 1167                WeTrust
# 1168               Ragnarok
# 1169                MaxCoin
# 1170                Expanse
# 1171           Helleniccoin
# 1172                   EBCH
# 1173                   Zoin
# 1174                  CHIPS
# 1175     Internet of People
# 1176                KekCoin
# 1177              Numeraire
# 1178         Monkey Project
# 1179           Lightpaycoin
# 1180               Forkcoin
# 1181              LogisCoin
# 1182      Bitcoin Incognito
# 1183             BitcoiNote
# 1184               e-Gulden
# 1185                   Hush
# 1186              Kronecoin
# 1187                Adzcoin
# 1188                  Rupee
# 1189                 YENTEN
# 1190               Actinium
#
# [1191 rows x 1 columns]

# %% [markdown]
# ### Which 5 coins have seen the greatest percentage growth in the last week?

# %%
# %%bigquery
# SELECT a.name
# FROM (SELECT name, ROW_NUMBER() OVER (ORDER BY percent_change_7d DESC) as row_num FROM `hokie-crazy.cryptocurrency.ticker`) a
# WHERE a.row_num <= 5
# Out:
#           name
# 0      BBSCoin
# 1   Cobrabytes
# 2    FREE Coin
# 3    PitisCoin
# 4  TRONCLASSIC

# %% [markdown]
# ### How many ticker symbols contain the letter "X"?

# %%
# %%bigquery
# SELECT COUNT(id)
# FROM `hokie-crazy.cryptocurrency.ticker`
# WHERE symbol like '%X%'
#
# #271
# Out:
#    f0_
# 0  271
