# %% [markdown]
# # CryptoCurrency Notebook

# %% [markdown]
# ### Install coinmarketcap
# This is a python wrapper to the cryptocurrency API.  More often than not, I try to leverage python wrappers over direct API calls, because many of them have already worked out the kinks, added error handling, etc.

# %%
# !pip install coinmarketcap
# Out:
# Collecting coinmarketcap
#   Downloading https://files.pythonhosted.org/packages/a8/da/c64662a91905017f237f5ff2778b68638946b0d6268513efadd4d1363669/coinmarketcap-5.0.3.tar.gz
# Requirement already satisfied: requests>=2.18.4 in /usr/local/envs/py2env/lib/python2.7/site-packages (from coinmarketcap) (2.18.4)
# Collecting requests_cache>=0.4.13 (from coinmarketcap)
#   Downloading https://files.pythonhosted.org/packages/00/62/9e45a38988cb48c474805a1626439f4d9a486a042bd077af888fa8b17a64/requests_cache-0.4.13-py2.py3-none-any.whl
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests>=2.18.4->coinmarketcap) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests>=2.18.4->coinmarketcap) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests>=2.18.4->coinmarketcap) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests>=2.18.4->coinmarketcap) (2018.8.13)
# Building wheels for collected packages: coinmarketcap
#   Running setup.py bdist_wheel for coinmarketcap ... done
#   Stored in directory: /content/.cache/pip/wheels/5c/73/ec/47f4d3160b8d215cc223937a3886eccfc690cd3dbb5152ab42
# Successfully built coinmarketcap
# Installing collected packages: requests-cache, coinmarketcap
# Successfully installed coinmarketcap-5.0.3 requests-cache-0.4.13

# %%
# !pip install google.cloud.logging
# Out:
# Collecting google.cloud.logging
#   Using cached https://files.pythonhosted.org/packages/20/9c/f0c9011b334f250977dd52bae260352587f86a9c6b03e770d6954d9c8405/google_cloud_logging-1.8.0-py2.py3-none-any.whl
# Requirement already satisfied: google-cloud-core<0.29dev,>=0.28.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google.cloud.logging) (0.28.1)
# Requirement already satisfied: google-api-core[grpc]<2.0.0dev,>=1.0.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google.cloud.logging) (1.5.0)
# Requirement already satisfied: protobuf>=3.4.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.0.0->google.cloud.logging) (3.5.2)
# Requirement already satisfied: pytz in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.0.0->google.cloud.logging) (2016.7)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.0.0->google.cloud.logging) (2.18.4)
# Requirement already satisfied: google-auth<2.0.0dev,>=0.4.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.0.0->google.cloud.logging) (1.5.1)
# Requirement already satisfied: futures>=3.2.0; python_version < "3.2" in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.0.0->google.cloud.logging) (3.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.5.3 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.0.0->google.cloud.logging) (1.5.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.0.0->google.cloud.logging) (1.10.0)
# Requirement already satisfied: setuptools>=34.0.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.0.0->google.cloud.logging) (40.0.0)
# Requirement already satisfied: grpcio>=1.8.2; extra == "grpc" in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.0.0->google.cloud.logging) (1.14.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.0.0->google.cloud.logging) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.0.0->google.cloud.logging) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.0.0->google.cloud.logging) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.0.0->google.cloud.logging) (2018.8.13)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-auth<2.0.0dev,>=0.4.0->google-api-core[grpc]<2.0.0dev,>=1.0.0->google.cloud.logging) (0.2.2)
# Requirement already satisfied: cachetools>=2.0.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-auth<2.0.0dev,>=0.4.0->google-api-core[grpc]<2.0.0dev,>=1.0.0->google.cloud.logging) (2.1.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-auth<2.0.0dev,>=0.4.0->google-api-core[grpc]<2.0.0dev,>=1.0.0->google.cloud.logging) (3.4.2)
# Requirement already satisfied: enum34>=1.0.4 in /usr/local/envs/py2env/lib/python2.7/site-packages (from grpcio>=1.8.2; extra == "grpc"->google-api-core[grpc]<2.0.0dev,>=1.0.0->google.cloud.logging) (1.1.6)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.1 in /usr/local/envs/py2env/lib/python2.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0.0dev,>=0.4.0->google-api-core[grpc]<2.0.0dev,>=1.0.0->google.cloud.logging) (0.4.4)
# Installing collected packages: google.cloud.logging
# Successfully installed google.cloud.logging

# %% [markdown]
# ### Install pandas
# For small amounts of data, I like to leverage pandas for data manipulation.

# %%
# !pip install pandas
# !pip install google.cloud.bigquery
# Out:
# Requirement already satisfied: pandas in /usr/local/envs/py2env/lib/python2.7/site-packages (0.22.0)
# Requirement already satisfied: python-dateutil in /usr/local/envs/py2env/lib/python2.7/site-packages (from pandas) (2.5.0)
# Requirement already satisfied: pytz>=2011k in /usr/local/envs/py2env/lib/python2.7/site-packages (from pandas) (2016.7)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from pandas) (1.14.0)
# Requirement already satisfied: six>=1.5 in /usr/local/envs/py2env/lib/python2.7/site-packages (from python-dateutil->pandas) (1.10.0)
# Collecting google.cloud.bigquery
#   Downloading https://files.pythonhosted.org/packages/72/e1/1ae3f8024e1d011bc567d54ec81e8c9afd08d107a326bd109e578475415d/google_cloud_bigquery-1.6.0-py2.py3-none-any.whl (83kB)
#     100% |████████████████████████████████| 92kB 3.4MB/s ta 0:00:011
# Requirement already satisfied: google-resumable-media>=0.2.1 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google.cloud.bigquery) (0.3.1)
# Requirement already satisfied: google-cloud-core<0.29dev,>=0.28.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google.cloud.bigquery) (0.28.1)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.0.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google.cloud.bigquery) (1.5.0)
# Requirement already satisfied: six in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-resumable-media>=0.2.1->google.cloud.bigquery) (1.10.0)
# Requirement already satisfied: protobuf>=3.4.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (3.5.2)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (2.18.4)
# Requirement already satisfied: pytz in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (2016.7)
# Requirement already satisfied: google-auth<2.0.0dev,>=0.4.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (1.5.1)
# Requirement already satisfied: futures>=3.2.0; python_version < "3.2" in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (3.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.5.3 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (1.5.3)
# Requirement already satisfied: setuptools>=34.0.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (40.0.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/envs/py2env/lib/python2.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (2018.8.13)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-auth<2.0.0dev,>=0.4.0->google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (0.2.2)
# Requirement already satisfied: cachetools>=2.0.0 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-auth<2.0.0dev,>=0.4.0->google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (2.1.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/envs/py2env/lib/python2.7/site-packages (from google-auth<2.0.0dev,>=0.4.0->google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (3.4.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.1 in /usr/local/envs/py2env/lib/python2.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0.0dev,>=0.4.0->google-api-core<2.0.0dev,>=1.0.0->google.cloud.bigquery) (0.4.4)
# google-cloud-dataflow 2.0.0 has requirement google-cloud-bigquery<0.24.0,>=0.23.0, but you'll have google-cloud-bigquery 1.6.0 which is incompatible.
# google-cloud-dataflow 2.0.0 has requirement httplib2<0.10,>=0.8, but you'll have httplib2 0.11.3 which is incompatible.
# google-cloud-dataflow 2.0.0 has requirement protobuf==3.2.0, but you'll have protobuf 3.5.2 which is incompatible.
# Installing collected packages: google.cloud.bigquery
# Successfully installed google.cloud.bigquery

# %% [markdown]
# ### Import csv, Market, Logging, and pandas
# Import the necessary libraries and setup the API connection.

# %%
import csv
from coinmarketcap import Market
import pandas as pd

coinmarketcap = Market()

import google.cloud.logging
client = google.cloud.logging.Client()

import logging

handler = client.get_default_handler()
cloud_logger = logging.getLogger('cloudLogger')
cloud_logger.setLevel(logging.INFO)
client.setup_logging(log_level=logging.INFO)

# %% [markdown]
# ### Max Loops
# By querying the listings, I get a number of records available in the ticker.  By doing this, I'll be able to control my loop later, so I get ticker information in chunks of 100 records (the max for that API).

# %%
try:
    listings_return = coinmarketcap.listings()
    listings_df = pd.DataFrame.from_dict(listings_return['data'])
    max_loop = listings_df['id'].count()

    logging.info('Total Listings: ' + str(max_loop))
  
except Exception as e:
    logging.critical("FAILED: " + str(e))
    raise ValueError(str(e))
# Out:
# Total Listings: 2112

# %% [markdown]
# ### Run the Loop
# Loop through the API to get every record.  This process needs to transpose the data correctly into columns and then append each loop to a persistent "full" dataframe.

# %%
try:
    j = 1
    while j < max_loop:
        ticker_return = coinmarketcap.ticker(start=j, limit=100)
        ticker_df = pd.DataFrame.from_dict(ticker_return['data'])
        if ticker_df.shape[0] != 0:
            ticker_trans = ticker_df.transpose()
            if j == 1:
                ticker_full = ticker_trans
            else:
                ticker_full = ticker_full.append(ticker_trans)
            j += 100
        logging.info('Listing: ' + str(j))
    
    logging.info('Dataframe Built')

except Exception as e:
    logging.critical("FAILED: " + str(e))
    raise ValueError(str(e))
    
ticker_full
# Out:
# Listing: 101
# Listing: 201
# Listing: 301
# Listing: 401
# Listing: 501
# Listing: 601
# Listing: 701
# Listing: 801
# Listing: 901
# Listing: 1001
# Listing: 1101
# Listing: 1201
# Listing: 1301
# Listing: 1401
# Listing: 1501
# Listing: 1601
# Listing: 1701
# Listing: 1801
# Listing: 1901
# Listing: 2001
# Listing: 2101
# Listing: 2201
# Dataframe Built
#      circulating_supply    id last_updated   max_supply  \
# 1           1.73359e+07     1   1540223382      2.1e+07
# 1027        1.02731e+08  1027   1540223383         None
# 1042        3.75211e+10  1042   1540223375         None
# 109         1.09557e+10   109   1540223410      2.1e+10
# 1104            1.1e+07  1104   1540223373         None
# 1168        8.68447e+06  1168   1540223373      2.1e+07
# 1169        5.67812e+07  1169   1540223371         None
# 118         2.88087e+10   118   1540223412         None
# 1214        1.11431e+08  1214   1540223377         None
# 1229              2e+06  1229   1540223371         None
# 1230        2.80859e+08  1230   1540223373         None
# 1274              1e+08  1274   1540223367         None
# 131         8.39564e+06   131   1540223415     1.89e+07
# 1320        9.98999e+08  1320   1540223373  9.98999e+08
# 1321        1.05466e+08  1321   1540223373         None
# 1343         9.9063e+07  1343   1540223373         None
# 1376            6.5e+07  1376   1540223373        1e+08
# 1437        5.06893e+06  1437   1540223377         None
# 1455        9.59242e+08  1455   1540223368         None
# 1518             728228  1518   1540223375         None
# 1521        1.10384e+08  1521   1540223368         None
# 1567        1.33248e+08  1567   1540223373  1.33248e+08
# 1586        1.05874e+08  1586   1540223377         None
# 1684          8.898e+07  1684   1540223377         None
# 1697              1e+09  1697   1540223373         None
# 1698        4.98864e+06  1698   1540223373      2.1e+07
# 1700         2.3302e+08  1700   1540223373         None
# 1703        5.28964e+07  1703   1540223377        1e+08
# 1710        2.03664e+06  1710   1540223373         None
# 1715              1e+08  1715   1540223387         None
# ...                 ...   ...          ...          ...
# 3299               None  3299   1540223395         None
# 3300               None  3300   1540223392         None
# 3310               None  3310   1540223395         None
# 337                None   337   1539096858         None
# 3385               None  3385   1540223391        1e+09
# 3425               None  3425   1540120254         None
# 3458               None  3458   1540223394         None
# 3461               None  3461   1540223397         None
# 3470               None  3470   1540223397         None
# 3473               None  3473   1540223396         None
# 353                None   353   1540020792         None
# 385                None   385   1538903117         None
# 411                None   411   1540110835         None
# 70                 None    70   1540206784         None
# 733                None   733   1540178910         None
# 841                None   841   1539864326         None
# 89                 None    89   1540223413         None
# 918                None   918   1540223369         None
# 2114               None  2114   1534576978         None
# 2331               None  2331   1525799359      1.6e+09
# 2409               None  2409   1535117806         None
# 3108               None  3108   1539694971         None
# 3190               None  3190   1540096369         None
# 3238               None  3238   1540223390         None
# 3260               None  3260   1539875696         None
# 3310               None  3310   1540223395         None
# 3425               None  3425   1540120254         None
# 3458               None  3458   1540223394         None
# 3461               None  3461   1540223397         None
# 3470               None  3470   1540223397         None
#
#                        name  \
# 1                   Bitcoin
# 1027               Ethereum
# 1042                Siacoin
# 109                DigiByte
# 1104                  Augur
# 1168                 Decred
# 1169                   PIVX
# 118                ReddCoin
# 1214                   Lisk
# 1229               DigixDAO
# 1230                  Steem
# 1274                  Waves
# 131                    Dash
# 1320                  Ardor
# 1321       Ethereum Classic
# 1343                Stratis
# 1376                    NEO
# 1437                  Zcash
# 1455                  Golem
# 1518                  Maker
# 1521                 Komodo
# 1567                   Nano
# 1586                    Ark
# 1684                   Qtum
# 1697  Basic Attention Token
# 1698                Horizen
# 1700              Aeternity
# 1703          Metaverse ETP
# 1710             Veritaseum
# 1715               MobileGo
# ...                     ...
# 3299              XRT Token
# 3300                BFFDoom
# 3310                ALLCOIN
# 337               CryptCoin
# 3385                   GIGA
# 3425             EmaratCoin
# 3458                 ZTCoin
# 3461       PlayCoin [ERC20]
# 3470           Dragon Token
# 3473                OBXcoin
# 353                   Hyper
# 385            Donationcoin
# 411                 SHACoin
# 70                 BetaCoin
# 733                Quotient
# 841               Sharkcoin
# 89                 Mooncoin
# 918                  Bubble
# 2114              BT2 [CST]
# 2331                ENTCash
# 2409       EtherDelta Token
# 3108               HighCoin
# 3190                Defense
# 3238             ABCC Token
# 3260               AMO Coin
# 3310                ALLCOIN
# 3425             EmaratCoin
# 3458                 ZTCoin
# 3461       PlayCoin [ERC20]
# 3470           Dragon Token
#
#                                                  quotes  rank symbol  \
# 1     {u'USD': {u'market_cap': 1.12632577238e+11, u'...     1    BTC
# 1027  {u'USD': {u'market_cap': 21037638491.0, u'perc...     2    ETH
# 1042  {u'USD': {u'market_cap': 255010373.0, u'percen...    37     SC
# 109   {u'USD': {u'market_cap': 248568875.0, u'percen...    39    DGB
# 1104  {u'USD': {u'market_cap': 144999567.0, u'percen...    51    REP
# 1168  {u'USD': {u'market_cap': 335408035.0, u'percen...    28    DCR
# 1169  {u'USD': {u'market_cap': 74006395.0, u'percent...    88   PIVX
# 118   {u'USD': {u'market_cap': 86700498.0, u'percent...    70    RDD
# 1214  {u'USD': {u'market_cap': 329900043.0, u'percen...    29    LSK
# 1229  {u'USD': {u'market_cap': 87278096.0, u'percent...    69    DGD
# 1230  {u'USD': {u'market_cap': 227950698.0, u'percen...    40  STEEM
# 1274  {u'USD': {u'market_cap': 195578256.0, u'percen...    44  WAVES
# 131   {u'USD': {u'market_cap': 1288558521.0, u'perce...    13   DASH
# 1320  {u'USD': {u'market_cap': 113755773.0, u'percen...    59   ARDR
# 1321  {u'USD': {u'market_cap': 1058595292.0, u'perce...    16    ETC
# 1343  {u'USD': {u'market_cap': 145066647.0, u'percen...    50  STRAT
# 1376  {u'USD': {u'market_cap': 1104319198.0, u'perce...    15    NEO
# 1437  {u'USD': {u'market_cap': 622272215.0, u'percen...    19    ZEC
# 1455  {u'USD': {u'market_cap': 154745727.0, u'percen...    48    GNT
# 1518  {u'USD': {u'market_cap': 495495313.0, u'percen...    22    MKR
# 1521  {u'USD': {u'market_cap': 141473387.0, u'percen...    52    KMD
# 1567  {u'USD': {u'market_cap': 265483280.0, u'percen...    35   NANO
# 1586  {u'USD': {u'market_cap': 79799027.0, u'percent...    78    ARK
# 1684  {u'USD': {u'market_cap': 393298320.0, u'percen...    26   QTUM
# 1697  {u'USD': {u'market_cap': 278041575.0, u'percen...    31    BAT
# 1698  {u'USD': {u'market_cap': 67329856.0, u'percent...    96    ZEN
# 1700  {u'USD': {u'market_cap': 297810132.0, u'percen...    30     AE
# 1703  {u'USD': {u'market_cap': 162755512.0, u'percen...    46    ETP
# 1710  {u'USD': {u'market_cap': 76816183.0, u'percent...    79   VERI
# 1715  {u'USD': {u'market_cap': 61903707.0, u'percent...   100    MGO
# ...                                                 ...   ...    ...
# 3299  {u'USD': {u'market_cap': None, u'percent_chang...  2010    XRT
# 3300  {u'USD': {u'market_cap': None, u'percent_chang...  2003    BFF
# 3310  {u'USD': {u'market_cap': None, u'percent_chang...  2075    ALC
# 337   {u'USD': {u'market_cap': None, u'percent_chang...  2058  CRYPT
# 3385  {u'USD': {u'market_cap': None, u'percent_chang...  2009     XG
# 3425  {u'USD': {u'market_cap': None, u'percent_chang...  2076    AEC
# 3458  {u'USD': {u'market_cap': None, u'percent_chang...  2077     ZT
# 3461  {u'USD': {u'market_cap': None, u'percent_chang...  2078    PLY
# 3470  {u'USD': {u'market_cap': None, u'percent_chang...  2079     DT
# 3473  {u'USD': {u'market_cap': None, u'percent_chang...  2055    OBX
# 353   {u'USD': {u'market_cap': None, u'percent_chang...  2059  HYPER
# 385   {u'USD': {u'market_cap': None, u'percent_chang...  2060    DON
# 411   {u'USD': {u'market_cap': None, u'percent_chang...  2061    SHA
# 70    {u'USD': {u'market_cap': None, u'percent_chang...  2056    BET
# 733   {u'USD': {u'market_cap': None, u'percent_chang...  2062    XQN
# 841   {u'USD': {u'market_cap': None, u'percent_chang...  2063    SAK
# 89    {u'USD': {u'market_cap': None, u'percent_chang...  2041   MOON
# 918   {u'USD': {u'market_cap': None, u'percent_chang...  2033    BUB
# 2114  {u'USD': {u'market_cap': None, u'percent_chang...  2110    BT2
# 2331  {u'USD': {u'market_cap': None, u'percent_chang...  2111    ENT
# 2409  {u'USD': {u'market_cap': None, u'percent_chang...  2112    EDT
# 3108  {u'USD': {u'market_cap': None, u'percent_chang...  2101  HIGHT
# 3190  {u'USD': {u'market_cap': None, u'percent_chang...  2102    DFS
# 3238  {u'USD': {u'market_cap': None, u'percent_chang...  2103     AT
# 3260  {u'USD': {u'market_cap': None, u'percent_chang...  2109    AMO
# 3310  {u'USD': {u'market_cap': None, u'percent_chang...  2104    ALC
# 3425  {u'USD': {u'market_cap': None, u'percent_chang...  2105    AEC
# 3458  {u'USD': {u'market_cap': None, u'percent_chang...  2106     ZT
# 3461  {u'USD': {u'market_cap': None, u'percent_chang...  2107    PLY
# 3470  {u'USD': {u'market_cap': None, u'percent_chang...  2108     DT
#
#      total_supply           website_slug
# 1     1.73359e+07                bitcoin
# 1027  1.02731e+08               ethereum
# 1042  3.75211e+10                siacoin
# 109   1.09557e+10               digibyte
# 1104      1.1e+07                  augur
# 1168  8.68447e+06                 decred
# 1169  5.67812e+07                   pivx
# 118   2.88087e+10               reddcoin
# 1214  1.26668e+08                   lisk
# 1229        2e+06               digixdao
# 1230  2.97833e+08                  steem
# 1274        1e+08                  waves
# 131   8.39564e+06                   dash
# 1320  9.98999e+08                  ardor
# 1321  1.05466e+08       ethereum-classic
# 1343   9.9063e+07                stratis
# 1376        1e+08                    neo
# 1437  5.06893e+06                  zcash
# 1455        1e+09   golem-network-tokens
# 1518        1e+06                  maker
# 1521  1.10384e+08                 komodo
# 1567  1.33248e+08                   nano
# 1586  1.37124e+08                    ark
# 1684   1.0098e+08                   qtum
# 1697      1.5e+09  basic-attention-token
# 1698  4.98864e+06                zencash
# 1700  2.73686e+08              aeternity
# 1703  5.67305e+07              metaverse
# 1710        1e+08             veritaseum
# 1715        1e+08               mobilego
# ...           ...                    ...
# 3299        5e+08              xrt-token
# 3300      1.6e+10                bffdoom
# 3310        1e+09                allcoin
# 337   6.07041e+06              cryptcoin
# 3385  1.65878e+08                   giga
# 3425  2.15216e+07             emaratcoin
# 3458        5e+08                 ztcoin
# 3461        1e+09         playcoin-erc20
# 3470  1.79502e+07           dragon-token
# 3473        1e+11                obxcoin
# 353          None                  hyper
# 385          None           donationcoin
# 411          None                shacoin
# 70           None               betacoin
# 733          None               quotient
# 841          None              sharkcoin
# 89    2.24851e+11               mooncoin
# 918        768753                 bubble
# 2114         None                bt2-cst
# 2331        6e+08                entcash
# 2409      1.5e+09       etherdelta-token
# 3108  2.74154e+09               highcoin
# 3190       850521                defense
# 3238  6.15562e+07             abcc-token
# 3260   1.9679e+10               amo-coin
# 3310        1e+09                allcoin
# 3425  2.15216e+07             emaratcoin
# 3458        5e+08                 ztcoin
# 3461        1e+09         playcoin-erc20
# 3470  1.79502e+07           dragon-token
#
# [2112 rows x 10 columns]

# %% [markdown]
# ### Parse Nested Data
# Within the resulting dataframe is another nested dictionary of data "quotes".  This step parses that data would and creates a new column for each value that I want to store.

# %%
try:
    ticker_full['market_cap'] = ticker_full.apply(lambda row: row.quotes['USD'][u'market_cap'], axis=1)
    ticker_full['percent_change_7d'] = ticker_full.apply(lambda row: row.quotes['USD'][u'percent_change_7d'], axis=1)
    ticker_full['price'] = ticker_full.apply(lambda row: row.quotes['USD'][u'price'], axis=1)
    ticker_full['percent_change_1h'] = ticker_full.apply(lambda row: row.quotes['USD'][u'percent_change_1h'], axis=1)
    ticker_full['volume_24h'] = ticker_full.apply(lambda row: row.quotes['USD'][u'volume_24h'], axis=1)
    ticker_full['percent_change_24h'] = ticker_full.apply(lambda row: row.quotes['USD'][u'percent_change_24h'], axis=1)
    
    logging.info('Dataframe Modified')
    
except Exception as e:
    logging.critical("FAILED: " + str(e))
    raise ValueError(str(e))    

ticker_full
# Out:
# Dataframe Modified
#      circulating_supply    id last_updated   max_supply  \
# 1           1.73359e+07     1   1540223382      2.1e+07
# 1027        1.02731e+08  1027   1540223383         None
# 1042        3.75211e+10  1042   1540223375         None
# 109         1.09557e+10   109   1540223410      2.1e+10
# 1104            1.1e+07  1104   1540223373         None
# 1168        8.68447e+06  1168   1540223373      2.1e+07
# 1169        5.67812e+07  1169   1540223371         None
# 118         2.88087e+10   118   1540223412         None
# 1214        1.11431e+08  1214   1540223377         None
# 1229              2e+06  1229   1540223371         None
# 1230        2.80859e+08  1230   1540223373         None
# 1274              1e+08  1274   1540223367         None
# 131         8.39564e+06   131   1540223415     1.89e+07
# 1320        9.98999e+08  1320   1540223373  9.98999e+08
# 1321        1.05466e+08  1321   1540223373         None
# 1343         9.9063e+07  1343   1540223373         None
# 1376            6.5e+07  1376   1540223373        1e+08
# 1437        5.06893e+06  1437   1540223377         None
# 1455        9.59242e+08  1455   1540223368         None
# 1518             728228  1518   1540223375         None
# 1521        1.10384e+08  1521   1540223368         None
# 1567        1.33248e+08  1567   1540223373  1.33248e+08
# 1586        1.05874e+08  1586   1540223377         None
# 1684          8.898e+07  1684   1540223377         None
# 1697              1e+09  1697   1540223373         None
# 1698        4.98864e+06  1698   1540223373      2.1e+07
# 1700         2.3302e+08  1700   1540223373         None
# 1703        5.28964e+07  1703   1540223377        1e+08
# 1710        2.03664e+06  1710   1540223373         None
# 1715              1e+08  1715   1540223387         None
# ...                 ...   ...          ...          ...
# 3299               None  3299   1540223395         None
# 3300               None  3300   1540223392         None
# 3310               None  3310   1540223395         None
# 337                None   337   1539096858         None
# 3385               None  3385   1540223391        1e+09
# 3425               None  3425   1540120254         None
# 3458               None  3458   1540223394         None
# 3461               None  3461   1540223397         None
# 3470               None  3470   1540223397         None
# 3473               None  3473   1540223396         None
# 353                None   353   1540020792         None
# 385                None   385   1538903117         None
# 411                None   411   1540110835         None
# 70                 None    70   1540206784         None
# 733                None   733   1540178910         None
# 841                None   841   1539864326         None
# 89                 None    89   1540223413         None
# 918                None   918   1540223369         None
# 2114               None  2114   1534576978         None
# 2331               None  2331   1525799359      1.6e+09
# 2409               None  2409   1535117806         None
# 3108               None  3108   1539694971         None
# 3190               None  3190   1540096369         None
# 3238               None  3238   1540223390         None
# 3260               None  3260   1539875696         None
# 3310               None  3310   1540223395         None
# 3425               None  3425   1540120254         None
# 3458               None  3458   1540223394         None
# 3461               None  3461   1540223397         None
# 3470               None  3470   1540223397         None
#
#                        name  \
# 1                   Bitcoin
# 1027               Ethereum
# 1042                Siacoin
# 109                DigiByte
# 1104                  Augur
# 1168                 Decred
# 1169                   PIVX
# 118                ReddCoin
# 1214                   Lisk
# 1229               DigixDAO
# 1230                  Steem
# 1274                  Waves
# 131                    Dash
# 1320                  Ardor
# 1321       Ethereum Classic
# 1343                Stratis
# 1376                    NEO
# 1437                  Zcash
# 1455                  Golem
# 1518                  Maker
# 1521                 Komodo
# 1567                   Nano
# 1586                    Ark
# 1684                   Qtum
# 1697  Basic Attention Token
# 1698                Horizen
# 1700              Aeternity
# 1703          Metaverse ETP
# 1710             Veritaseum
# 1715               MobileGo
# ...                     ...
# 3299              XRT Token
# 3300                BFFDoom
# 3310                ALLCOIN
# 337               CryptCoin
# 3385                   GIGA
# 3425             EmaratCoin
# 3458                 ZTCoin
# 3461       PlayCoin [ERC20]
# 3470           Dragon Token
# 3473                OBXcoin
# 353                   Hyper
# 385            Donationcoin
# 411                 SHACoin
# 70                 BetaCoin
# 733                Quotient
# 841               Sharkcoin
# 89                 Mooncoin
# 918                  Bubble
# 2114              BT2 [CST]
# 2331                ENTCash
# 2409       EtherDelta Token
# 3108               HighCoin
# 3190                Defense
# 3238             ABCC Token
# 3260               AMO Coin
# 3310                ALLCOIN
# 3425             EmaratCoin
# 3458                 ZTCoin
# 3461       PlayCoin [ERC20]
# 3470           Dragon Token
#
#                                                  quotes  rank symbol  \
# 1     {u'USD': {u'market_cap': 1.12632577238e+11, u'...     1    BTC
# 1027  {u'USD': {u'market_cap': 21037638491.0, u'perc...     2    ETH
# 1042  {u'USD': {u'market_cap': 255010373.0, u'percen...    37     SC
# 109   {u'USD': {u'market_cap': 248568875.0, u'percen...    39    DGB
# 1104  {u'USD': {u'market_cap': 144999567.0, u'percen...    51    REP
# 1168  {u'USD': {u'market_cap': 335408035.0, u'percen...    28    DCR
# 1169  {u'USD': {u'market_cap': 74006395.0, u'percent...    88   PIVX
# 118   {u'USD': {u'market_cap': 86700498.0, u'percent...    70    RDD
# 1214  {u'USD': {u'market_cap': 329900043.0, u'percen...    29    LSK
# 1229  {u'USD': {u'market_cap': 87278096.0, u'percent...    69    DGD
# 1230  {u'USD': {u'market_cap': 227950698.0, u'percen...    40  STEEM
# 1274  {u'USD': {u'market_cap': 195578256.0, u'percen...    44  WAVES
# 131   {u'USD': {u'market_cap': 1288558521.0, u'perce...    13   DASH
# 1320  {u'USD': {u'market_cap': 113755773.0, u'percen...    59   ARDR
# 1321  {u'USD': {u'market_cap': 1058595292.0, u'perce...    16    ETC
# 1343  {u'USD': {u'market_cap': 145066647.0, u'percen...    50  STRAT
# 1376  {u'USD': {u'market_cap': 1104319198.0, u'perce...    15    NEO
# 1437  {u'USD': {u'market_cap': 622272215.0, u'percen...    19    ZEC
# 1455  {u'USD': {u'market_cap': 154745727.0, u'percen...    48    GNT
# 1518  {u'USD': {u'market_cap': 495495313.0, u'percen...    22    MKR
# 1521  {u'USD': {u'market_cap': 141473387.0, u'percen...    52    KMD
# 1567  {u'USD': {u'market_cap': 265483280.0, u'percen...    35   NANO
# 1586  {u'USD': {u'market_cap': 79799027.0, u'percent...    78    ARK
# 1684  {u'USD': {u'market_cap': 393298320.0, u'percen...    26   QTUM
# 1697  {u'USD': {u'market_cap': 278041575.0, u'percen...    31    BAT
# 1698  {u'USD': {u'market_cap': 67329856.0, u'percent...    96    ZEN
# 1700  {u'USD': {u'market_cap': 297810132.0, u'percen...    30     AE
# 1703  {u'USD': {u'market_cap': 162755512.0, u'percen...    46    ETP
# 1710  {u'USD': {u'market_cap': 76816183.0, u'percent...    79   VERI
# 1715  {u'USD': {u'market_cap': 61903707.0, u'percent...   100    MGO
# ...                                                 ...   ...    ...
# 3299  {u'USD': {u'market_cap': None, u'percent_chang...  2010    XRT
# 3300  {u'USD': {u'market_cap': None, u'percent_chang...  2003    BFF
# 3310  {u'USD': {u'market_cap': None, u'percent_chang...  2075    ALC
# 337   {u'USD': {u'market_cap': None, u'percent_chang...  2058  CRYPT
# 3385  {u'USD': {u'market_cap': None, u'percent_chang...  2009     XG
# 3425  {u'USD': {u'market_cap': None, u'percent_chang...  2076    AEC
# 3458  {u'USD': {u'market_cap': None, u'percent_chang...  2077     ZT
# 3461  {u'USD': {u'market_cap': None, u'percent_chang...  2078    PLY
# 3470  {u'USD': {u'market_cap': None, u'percent_chang...  2079     DT
# 3473  {u'USD': {u'market_cap': None, u'percent_chang...  2055    OBX
# 353   {u'USD': {u'market_cap': None, u'percent_chang...  2059  HYPER
# 385   {u'USD': {u'market_cap': None, u'percent_chang...  2060    DON
# 411   {u'USD': {u'market_cap': None, u'percent_chang...  2061    SHA
# 70    {u'USD': {u'market_cap': None, u'percent_chang...  2056    BET
# 733   {u'USD': {u'market_cap': None, u'percent_chang...  2062    XQN
# 841   {u'USD': {u'market_cap': None, u'percent_chang...  2063    SAK
# 89    {u'USD': {u'market_cap': None, u'percent_chang...  2041   MOON
# 918   {u'USD': {u'market_cap': None, u'percent_chang...  2033    BUB
# 2114  {u'USD': {u'market_cap': None, u'percent_chang...  2110    BT2
# 2331  {u'USD': {u'market_cap': None, u'percent_chang...  2111    ENT
# 2409  {u'USD': {u'market_cap': None, u'percent_chang...  2112    EDT
# 3108  {u'USD': {u'market_cap': None, u'percent_chang...  2101  HIGHT
# 3190  {u'USD': {u'market_cap': None, u'percent_chang...  2102    DFS
# 3238  {u'USD': {u'market_cap': None, u'percent_chang...  2103     AT
# 3260  {u'USD': {u'market_cap': None, u'percent_chang...  2109    AMO
# 3310  {u'USD': {u'market_cap': None, u'percent_chang...  2104    ALC
# 3425  {u'USD': {u'market_cap': None, u'percent_chang...  2105    AEC
# 3458  {u'USD': {u'market_cap': None, u'percent_chang...  2106     ZT
# 3461  {u'USD': {u'market_cap': None, u'percent_chang...  2107    PLY
# 3470  {u'USD': {u'market_cap': None, u'percent_chang...  2108     DT
#
#      total_supply           website_slug    market_cap  percent_change_7d  \
# 1     1.73359e+07                bitcoin  1.126326e+11              -2.06
# 1027  1.02731e+08               ethereum  2.103764e+10              -2.23
# 1042  3.75211e+10                siacoin  2.550104e+08               4.83
# 109   1.09557e+10               digibyte  2.485689e+08              -5.93
# 1104      1.1e+07                  augur  1.449996e+08               6.95
# 1168  8.68447e+06                 decred  3.354080e+08              -0.79
# 1169  5.67812e+07                   pivx  7.400640e+07              15.87
# 118   2.88087e+10               reddcoin  8.670050e+07              -9.20
# 1214  1.26668e+08                   lisk  3.299000e+08               2.57
# 1229        2e+06               digixdao  8.727810e+07              -0.21
# 1230  2.97833e+08                  steem  2.279507e+08              -2.59
# 1274        1e+08                  waves  1.955783e+08              -2.55
# 131   8.39564e+06                   dash  1.288559e+09              -5.69
# 1320  9.98999e+08                  ardor  1.137558e+08              -1.11
# 1321  1.05466e+08       ethereum-classic  1.058595e+09               2.70
# 1343   9.9063e+07                stratis  1.450666e+08               0.44
# 1376        1e+08                    neo  1.104319e+09               4.21
# 1437  5.06893e+06                  zcash  6.222722e+08               7.75
# 1455        1e+09   golem-network-tokens  1.547457e+08               8.05
# 1518        1e+06                  maker  4.954953e+08               1.40
# 1521  1.10384e+08                 komodo  1.414734e+08               8.32
# 1567  1.33248e+08                   nano  2.654833e+08               7.94
# 1586  1.37124e+08                    ark  7.979903e+07               5.57
# 1684   1.0098e+08                   qtum  3.932983e+08              21.99
# 1697      1.5e+09  basic-attention-token  2.780416e+08              54.48
# 1698  4.98864e+06                zencash  6.732986e+07               0.10
# 1700  2.73686e+08              aeternity  2.978101e+08               8.53
# 1703  5.67305e+07              metaverse  1.627555e+08              -4.60
# 1710        1e+08             veritaseum  7.681618e+07              76.44
# 1715        1e+08               mobilego  6.190371e+07              28.52
# ...           ...                    ...           ...                ...
# 3299        5e+08              xrt-token           NaN              23.83
# 3300      1.6e+10                bffdoom           NaN              -8.53
# 3310        1e+09                allcoin           NaN                NaN
# 337   6.07041e+06              cryptcoin           NaN                NaN
# 3385  1.65878e+08                   giga           NaN             -49.05
# 3425  2.15216e+07             emaratcoin           NaN              85.08
# 3458        5e+08                 ztcoin           NaN                NaN
# 3461        1e+09         playcoin-erc20           NaN                NaN
# 3470  1.79502e+07           dragon-token           NaN                NaN
# 3473        1e+11                obxcoin           NaN                NaN
# 353          None                  hyper           NaN              -2.84
# 385          None           donationcoin           NaN                NaN
# 411          None                shacoin           NaN              62.43
# 70           None               betacoin           NaN             -18.48
# 733          None               quotient           NaN              -8.15
# 841          None              sharkcoin           NaN               5.71
# 89    2.24851e+11               mooncoin           NaN                NaN
# 918        768753                 bubble           NaN              46.35
# 2114         None                bt2-cst           NaN                NaN
# 2331        6e+08                entcash           NaN                NaN
# 2409      1.5e+09       etherdelta-token           NaN                NaN
# 3108  2.74154e+09               highcoin           NaN              -0.87
# 3190       850521                defense           NaN                NaN
# 3238  6.15562e+07             abcc-token           NaN                NaN
# 3260   1.9679e+10               amo-coin           NaN             -12.24
# 3310        1e+09                allcoin           NaN                NaN
# 3425  2.15216e+07             emaratcoin           NaN              85.08
# 3458        5e+08                 ztcoin           NaN                NaN
# 3461        1e+09         playcoin-erc20           NaN                NaN
# 3470  1.79502e+07           dragon-token           NaN                NaN
#
#             price  percent_change_1h    volume_24h  percent_change_24h
# 1     6497.061867              -0.04  3.623062e+09               -0.58
# 1027   204.784708               0.01  1.367291e+09               -1.06
# 1042     0.006796               0.16  4.109611e+06               -2.35
# 109      0.022689              -1.05  2.299384e+06               -3.71
# 1104    13.181779               1.08  1.665098e+06                0.10
# 1168    38.621579              -0.20  5.831934e+05                0.98
# 1169     1.303362               0.63  6.044741e+05                0.32
# 118      0.003010              -0.23  6.508855e+05               -4.45
# 1214     2.960580               0.14  6.456297e+06                1.53
# 1229    43.639048              -0.54  4.339191e+05               -3.69
# 1230     0.811620              -0.18  7.743829e+05               -1.63
# 1274     1.955783              -0.09  5.888969e+06               -2.34
# 131    153.479435               0.07  1.075779e+08               -1.57
# 1320     0.113870              -0.10  9.726113e+05               -1.69
# 1321    10.037357              -0.26  1.814363e+08                3.45
# 1343     1.464388               2.13  6.873445e+05                1.43
# 1376    16.989526               2.06  1.651598e+08                1.17
# 1437   122.762015              -0.26  8.829545e+07               -2.51
# 1455     0.161321               0.59  1.608550e+06               -1.31
# 1518   680.412548              -0.06  5.010198e+05               -0.31
# 1521     1.281643              -1.46  1.041142e+06               -1.57
# 1567     1.992395              -0.24  3.926344e+06               -4.01
# 1586     0.753718               0.36  5.508412e+05               -5.89
# 1684     4.420077               1.96  1.884569e+08                2.97
# 1697     0.278042               1.28  3.181676e+07               15.19
# 1698    13.496642              -1.13  3.968431e+05               -3.70
# 1700     1.278043              -0.18  1.200579e+07               -7.80
# 1703     3.076875               0.43  6.507927e+06               -1.33
# 1710    37.717013               0.65  8.507285e+05               23.51
# 1715     0.619037               1.11  1.079916e+07               17.69
# ...           ...                ...           ...                 ...
# 3299     0.000238              -0.05  5.315004e+01               27.89
# 3300     0.000002              -0.05  8.196565e+01               -1.19
# 3310     0.015267                NaN           NaN                 NaN
# 337      0.050202                NaN           NaN                 NaN
# 3385     0.000066              -0.09  5.413154e+01                0.92
# 3425     0.119393                NaN           NaN                 NaN
# 3458     0.127832                NaN           NaN                 NaN
# 3461     0.132404                NaN           NaN                 NaN
# 3470     1.498772                NaN           NaN                 NaN
# 3473     0.006475              -0.01  1.293785e-02              -25.27
# 353      0.008255                NaN           NaN                 NaN
# 385      0.000262                NaN           NaN                 NaN
# 411      0.000323                NaN           NaN                 NaN
# 70       0.000974                NaN           NaN               -0.34
# 733      0.001934                NaN           NaN               -2.30
# 841      0.002666                NaN           NaN                 NaN
# 89       0.000026               2.87  3.594440e+00               -8.67
# 918      0.009325              -0.13  4.702238e+00                 NaN
# 2114     5.323106                NaN           NaN                 NaN
# 2331     0.024932                NaN           NaN                 NaN
# 2409     0.001109                NaN           NaN                 NaN
# 3108     0.000007                NaN           NaN                 NaN
# 3190     0.003948                NaN           NaN                 NaN
# 3238     0.346325                NaN           NaN                 NaN
# 3260     0.001950                NaN           NaN                 NaN
# 3310     0.015267                NaN           NaN                 NaN
# 3425     0.119393                NaN           NaN                 NaN
# 3458     0.127832                NaN           NaN                 NaN
# 3461     0.132404                NaN           NaN                 NaN
# 3470     1.498772                NaN           NaN                 NaN
#
# [2112 rows x 16 columns]

# %% [markdown]
# ### Drop to CSV
# Using the pandas function to create a CSV from the dataframe, I create a file from the df without the nested quotes column, which has now been split into their own columns.

# %%
try:
    ticker_full.drop(columns=['quotes']).to_csv('cryptocurrency_details.csv',index=False, quoting=csv.QUOTE_NONNUMERIC)
    logging.info('CSV File Generated')
    
except Exception as e:
    logging.critical("FAILED: " + str(e))
    raise ValueError(str(e))
# Out:
# CSV File Generated

# %% [markdown]
# ### gsutil - Copy File to GCS
# __Note:__ The bucket was created manually within the GUI when I created the project.  This could have been done through the command line, as well, but was easier in the interface since I was already there.

# %%
# !gsutil cp cryptocurrency_details.csv gs://hokie-crazy-public/cryptocurrency/cryptocurrent_details.csv
# Out:
# Updates are available for some Cloud SDK components.  To install them,
# please run:
#   $ gcloud components update
#
# Copying file://cryptocurrency_details.csv [Content-Type=text/csv]...
# / [1 files][267.7 KiB/267.7 KiB]
# Operation completed over 1 objects/267.7 KiB.

# %% [markdown]
# ### gsutil - Make the bucket public
# __Note:__ This command adds all users as a read-only user to the bucket where the file above is located.

# %%
# !gsutil iam ch allUsers:objectViewer gs://hokie-crazy-public

# %% [markdown]
# ### Load the BigQuery Library
# __Note:__ This command allows me to use %%bigquery magics to execute queries.  Might not be necessary to load this in DataLab, but to be safe...

# %%
# %load_ext google.cloud.bigquery

# %% [markdown]
# ### How many coins have a USD price greater than $8,000?

# %%
# %%bigquery
# SELECT COUNT(id)
# FROM `hokie-crazy.cryptocurrency.ticker`
# WHERE price > 8000
#
# #3
# Out:
#    f0_
# 0    3

# %% [markdown]
# ### What is the total market cap of the top 100 cryptocurrencies (in USD)?

# %%
# %%bigquery
# SELECT SUM(market_cap)
# FROM (SELECT market_cap, ROW_NUMBER() OVER (ORDER BY market_cap DESC) as row_num FROM `hokie-crazy.cryptocurrency.ticker`) a
# WHERE a.row_num <= 100
#
# #2.027954e+11
# Out:
#             f0_
# 0  2.027954e+11

# %% [markdown]
# ### Which coins have an available supply less than $5M?

# %%
# %%bigquery
# SELECT name
# FROM `hokie-crazy.cryptocurrency.ticker`
# WHERE circulating_supply * price < 5000000
# Out:
#                        name
# 0              CryptoCarbon
# 1                MarteXcoin
# 2                  Bitcloud
# 3      Ultimate Secure Cash
# 4                  BriaCoin
# 5                  Golfcoin
# 6                   Granite
# 7      Gold Pressed Latinum
# 8               HoboNickels
# 9                 CacheCoin
# 10              StarCredits
# 11               Artex Coin
# 12                 ChanCoin
# 13             Coimatic 3.0
# 14                     Ergo
# 15                 Fastcoin
# 16                GrandCoin
# 17                 Megacoin
# 18                 Nyancoin
# 19               EuropeCoin
# 20                  Polcoin
# 21    Uniform Fiscal Object
# 22            Litecoin Plus
# 23                Quebecoin
# 24                  PLNcoin
# 25                Virtacoin
# 26                  Neutron
# 27             MonetaryUnit
# 28                     Bata
# 29              Bolivarcoin
# ...                     ...
# 1161            Tidex Token
# 1162                  Bodhi
# 1163                    AC3
# 1164                  Semux
# 1165                Xchange
# 1166                 Dinero
# 1167                WeTrust
# 1168               Ragnarok
# 1169                MaxCoin
# 1170                Expanse
# 1171           Helleniccoin
# 1172                   EBCH
# 1173                   Zoin
# 1174                  CHIPS
# 1175     Internet of People
# 1176                KekCoin
# 1177              Numeraire
# 1178         Monkey Project
# 1179           Lightpaycoin
# 1180               Forkcoin
# 1181              LogisCoin
# 1182      Bitcoin Incognito
# 1183             BitcoiNote
# 1184               e-Gulden
# 1185                   Hush
# 1186              Kronecoin
# 1187                Adzcoin
# 1188                  Rupee
# 1189                 YENTEN
# 1190               Actinium
#
# [1191 rows x 1 columns]

# %% [markdown]
# ### Which 5 coins have seen the greatest percentage growth in the last week?

# %%
# %%bigquery
# SELECT a.name
# FROM (SELECT name, ROW_NUMBER() OVER (ORDER BY percent_change_7d DESC) as row_num FROM `hokie-crazy.cryptocurrency.ticker`) a
# WHERE a.row_num <= 5
# Out:
#           name
# 0      BBSCoin
# 1   Cobrabytes
# 2    FREE Coin
# 3    PitisCoin
# 4  TRONCLASSIC

# %% [markdown]
# ### How many ticker symbols contain the letter "X"?

# %%
# %%bigquery
# SELECT COUNT(id)
# FROM `hokie-crazy.cryptocurrency.ticker`
# WHERE symbol like '%X%'
#
# #271
# Out:
#    f0_
# 0  271
